# %%
import pandas as pd
from scipy.stats import shapiro #Teste de normalidade
from scipy.stats import ttest_ind #Teste t de Student
from scipy.stats import wilcoxon #Teste de Wilcoxon

# %%
df = pd.read_csv('https://raw.githubusercontent.com/leprogramar/obsidian/master/Dissertacao-versoes/Dissertacao-versao-6/dados-filtrados-2.csv') # Esse Dataframe está hospedado no GitHub. Caso nao não carregue, procure pelo link.
#df = df.describe()
#pd.set_option('display.max_columns', None)
#df

# %% [markdown]
# # Teste altomatizado de **Shapiro-Wilk** para todas as as variáveis

# %%
numeric_df = df.select_dtypes(include=['number']) # Filtrando para o spript pegar apenas dados numéricos
results = {}
for column in numeric_df.columns:
    stat, p = shapiro(numeric_df[column].dropna())  # Remover valores NaN antes do teste (o teste de shapiro dá erro se tiver Nan)
    results[column] = {'Statistic': stat, 'p_value': p}  # Armazenando os resultados em um dicionário
results_df = pd.DataFrame(results).T  # Convertendo o dicionário para um DataFrame
results_df['Teste de normalidade'] = results_df['p_value'].apply(lambda p: 'Normal' if p > 0.05 else 'Não normal') # Classificando o valor de p
results_df.to_csv('shapiro_results.csv', index=True)
print(results_df)
# Out:
#                             Statistic   p_value Teste de normalidade
# tempo-50m-cap-aquec          0.770920  0.006417           Não normal
# tempo-50m-plac-aquec         0.761119  0.004875           Não normal
# tempo-50m-cap-nnaquec        0.786787  0.010014           Não normal
# tempo-50m-plac-nnaquec       0.800984  0.014903           Não normal
# tempo-15m-cap-aquec          0.691617  0.000697           Não normal
# tempo-15m-plac-aquec         0.706765  0.001064           Não normal
# tempo-15m-cap-nnaquec        0.755062  0.004113           Não normal
# tempo-15m-plac-nnaquec       0.765936  0.005580           Não normal
# tempo-35m-cap-aquec          0.726346  0.001839           Não normal
# tempo-35m-plac-aquec         0.803666  0.016064           Não normal
# tempo-35m-cap-nnaquec        0.742681  0.002907           Não normal
# tempo-35m-plac-nnaquec       0.719463  0.001517           Não normal
# lac-pre-cap-aquec            0.931671  0.464532               Normal
# lac-pre-plac-aquec           0.941897  0.574304               Normal
# lac-pre-cap-nnaquec          0.903175  0.237317               Normal
# lac-pre-plac-nnaquec         0.837802  0.041526           Não normal
# lac-pos-1min-cap-aquec       0.905794  0.253334               Normal
# lac-pos-1min-plac-aquec      0.943887  0.597015               Normal
# lac-pos-1min-cap-nnaquec     0.849313  0.057005               Normal
# lac-pos-1min-plac-nnaquec    0.962504  0.814007               Normal
# lac-pos-3min-cap-aquec       0.913174  0.303511               Normal
# lac-pos-3min-plac-aquec      0.927276  0.421639               Normal
# lac-pos-3min-cap-nnaquec     0.932279  0.470682               Normal
# lac-pos-3min-plac-nnaquec    0.973799  0.923662               Normal
# pse-cap-aquec                0.805041  0.016694           Não normal
# pse-plac-aquec               0.655271  0.000254           Não normal
# pse-cap-nnaquec              0.780940  0.008500           Não normal
# pse-plac-nnaquec             0.655271  0.000254           Não normal
# altura-salto1-cap-aquec      0.958615  0.769977               Normal
# altura-salto2-cap-aquec      0.945220  0.612416               Normal
# altura-salto3-cap-aquec      0.934330  0.491805               Normal
# media-salto-cap-aquec        0.949782  0.665918               Normal
# altura-salto1-plac-aquec     0.942955  0.586344               Normal
# altura-salto2-plac-aquec     0.927787  0.426477               Normal
# altura-salto3-plac-aquec     0.913415  0.305283               Normal
# media-salto-plac-aquec       0.963477  0.824674               Normal
# altura-salto1-cap-nnaquec    0.915392  0.320120               Normal
# altura-salto2-cap-nnaquec    0.935453  0.503613               Normal
# altura-salto3-cap-nnaquec    0.956235  0.742236               Normal
# media-salto-cap-nnaquec      0.927769  0.426309               Normal
# altura-salto1-plac-nnaquec   0.949949  0.667895               Normal
# altura-salto2-plac-nnaquec   0.927655  0.425228               Normal
# altura-salto3-plac-nnaquec   0.964728  0.838137               Normal
# media-salto-plac-nnaquec     0.940562  0.559287               Normal
# motivacao-cap-aquec          0.887145  0.157438               Normal
# motivacao-plac-aquec         0.897317  0.204674               Normal
# motivacao-cap-nnaquec        0.902627  0.234080               Normal
# motivacao-plac-nnaquec       0.945940  0.620779               Normal
# preparacao-cap-aquec         0.906083  0.255153               Normal
# preparacao-plac-aquec        0.852575  0.062330               Normal
# preparacao-cap-nnaquec       0.853934  0.064689               Normal
# preparacao-plac-nnaquec      0.850362  0.058669               Normal
# brums-vigor-cap-aquec        0.940587  0.559565               Normal
# brums-vigor-plac-aquec       0.897348  0.204834               Normal
# brums-vigor-cap-nnaquec      0.905641  0.252373               Normal
# brums-vigor-plac-nnaquec     0.915880  0.323873               Normal
# brums-fadiga-cap-aquec       0.843602  0.048728           Não normal
# brums-fadiga-plac-aquec      0.879948  0.130315               Normal
# brums-fadiga-cap-nnaquec     0.870983  0.102637               Normal
# brums-fadiga-plac-nnaquec    0.969915  0.890053               Normal

# %% [markdown]
# ### **Teste de Hipótese**
#
# 1. Para variáveis com distribuição normal, foi realizado o teste **t de Student**.
# 2. Para variáveis com distribuição não normal, foi adotado o teste **de Wilcoxon**.
# 3. Para todos os testes, a hipótese nula (H0) foi rejeitada se \( p < 0,05 \).

# %% [markdown]
# ## Teste altomatizado de **t de Student**  para as variáveis setadas do dicionário.

# %%
# Dicionário de variáveis:

calculos_test_t = {
    #Tempo 50 metros
    "tempo-50m-cap_VS_plc_aquec": {
        "colun1": "tempo-50m-cap-aquec",
        "colun2": "tempo-50m-plac-aquec"
    },
    "tempo-50m-cap_VS_plc_nnaquec": {
        "colun1": "tempo-50m-cap-nnaquec",
        "colun2": "tempo-50m-plac-nnaquec"
    },
    "tempo-50m-cap_aquec_VS_cap_nnaquec": {
        "colun1": "tempo-50m-cap-nnaquec",
        "colun2": "tempo-50m-cap-aquec"
    },
    "tempo-50m-plc_aquec_VS_plc_nnaquec": {
        "colun1": "tempo-50m-plac-nnaquec",
        "colun2": "tempo-50m-plac-aquec"
    },

    #Tempo 15 metros
        "tempo-15m-cap_VS_plc_aquec": {
        "colun1": "tempo-15m-cap-aquec",
        "colun2": "tempo-15m-plac-aquec"
    },
    "tempo-15m-cap_VS_plc_nnaquec": {
        "colun1": "tempo-15m-cap-nnaquec",
        "colun2": "tempo-15m-plac-nnaquec"
    },
    "tempo-15m-cap_aquec_VS_cap_nnaquec": {
        "colun1": "tempo-15m-cap-nnaquec",
        "colun2": "tempo-15m-cap-aquec"
    },
    "tempo-15m-plc_aquec_VS_plc_nnaquec": {
        "colun1": "tempo-15m-plac-nnaquec",
        "colun2": "tempo-15m-plac-aquec"
    },


    #Tempo 35 metros
    "tempo-35m-cap_aquec_VS_plc_aquec": {
        "colun1": "tempo-35m-cap-aquec",
        "colun2": "tempo-35m-plac-aquec"
    },
    "tempo-35m-cap_nnaquec_VS_plc_nnaquec": {
        "colun1": "tempo-35m-cap-nnaquec",
        "colun2": "tempo-35m-plac-nnaquec"
    },
    "tempo-35m-cap_aquec_VS_cap_nnaquec": {
        "colun1": "tempo-35m-cap-nnaquec",
        "colun2": "tempo-35m-cap-aquec"
    },
    "tempo-35m-plc_aquec_VS_plc_nnaquec": {
        "colun1": "tempo-35m-plac-nnaquec",
        "colun2": "tempo-35m-plac-aquec"
    },

    #Lactato pré
    "lactato-pre-cap_VS_plc_aquec": {
        "colun1": "lac-pre-cap-aquec",
        "colun2": "lac-pre-plac-aquec"
    },
    "lactato-pre-cap_VS_plc_nnaquec": {
        "colun1": "lac-pre-cap-nnaquec",
        "colun2": "lac-pre-plac-nnaquec"
    },
    "lactato-pre-cap_aquec_VS_cap_nnaquec": {
        "colun1": "lac-pre-cap-nnaquec",
        "colun2": "lac-pre-cap-aquec"
    },
    "lactato-pre-plc_aquec_VS_plc_nnaquec": {
        "colun1": "lac-pre-plac-nnaquec",
        "colun2": "lac-pre-plac-aquec"
    },
    #Lactato pós 1 min
    "lactato-pos_1min_cap_VS_plc_aquec": {
        "colun1": "lac-pos-1min-cap-aquec",
        "colun2": "lac-pos-1min-plac-aquec"
    },
    "lactato-pos_1min_cap_VS_plc_nnaquec": {
        "colun1": "lac-pos-1min-cap-nnaquec",
        "colun2": "lac-pos-1min-plac-nnaquec"
    },
    "lactato-pos_1min_cap_aquec_VS_cap_nnaquec": {
        "colun1": "lac-pos-1min-cap-nnaquec",
        "colun2": "lac-pos-1min-cap-aquec"
    },
    "lactato-pos_1min_plc_aquec_VS_plc_nnaquec": {
        "colun1": "lac-pos-1min-plac-nnaquec",
        "colun2": "lac-pos-1min-plac-aquec"
    },

    #Lactato pos 3 min
        "lactato-pos_3min_cap_VS_plc_aquec": {
        "colun1": "lac-pos-3min-cap-aquec",
        "colun2": "lac-pos-3min-plac-aquec"
    },
    "lactato-pos_3min_cap_VS_plc_nnaquec": {
        "colun1": "lac-pos-3min-cap-nnaquec",
        "colun2": "lac-pos-3min-plac-nnaquec"
    },
    "lactato-pos_3min_cap_aquec_VS_cap_nnaquec": {
        "colun1": "lac-pos-3min-cap-nnaquec",
        "colun2": "lac-pos-3min-cap-aquec"
    },
    "lactato-pos_3min_plc_aquec_VS_plc_nnaquec": {
        "colun1": "lac-pos-3min-plac-nnaquec",
        "colun2": "lac-pos-3min-plac-aquec"
    },

    #SCM
    "scm-cap_VS_plc_aquec": {
        "colun1": "media-salto-cap-aquec",
        "colun2": "media-salto-plac-aquec"
    },
    "scm-cap_VS_plc_nnaquec": {
        "colun1": "media-salto-cap-nnaquec",
        "colun2": "media-salto-plac-nnaquec"
    },
    "scm-cap_aquec_VS_cap_nnaquec": {
        "colun1": "media-salto-cap-aquec",
        "colun2": "media-salto-cap-nnaquec"
    },
    "scm-plc_aquec_VS_plc_nnaquec": {
        "colun1": "media-salto-plac-aquec",
        "colun2": "media-salto-plac-nnaquec"
    },

    #pse
    "pse-cap_VS_plc_aquec": {
        "colun1": "pse-cap-aquec",
        "colun2": "pse-plac-aquec"
    },
    "pse-cap_VS_plc_nnaquec": {
        "colun1": "pse-cap-nnaquec",
        "colun2": "pse-plac-nnaquec"
    },
    "pse-cap_aquec_VS_cap_nnaquec": {
        "colun1": "pse-cap-nnaquec",
        "colun2": "pse-cap-aquec"
    },
    "pse-plc_aquec_VS_plc_nnaquec": {
        "colun1": "pse-plac-nnaquec",
        "colun2": "pse-plac-aquec"
    },

    #motivacao
    "motivacao-cap_VS_plc_aquec": {
        "colun1": "motivacao-cap-aquec",
        "colun2": "motivacao-plac-aquec"
    },
    "motivacao-cap_VS_plc_nnaquec": {
        "colun1": "motivacao-cap-nnaquec",
        "colun2": "motivacao-plac-nnaquec"
    },
    "motivacao-cap_aquec_VS_cap_nnaquec": {
        "colun1": "motivacao-cap-nnaquec",
        "colun2": "motivacao-cap-aquec"
    },
    "motivacao-plc_aquec_VS_plc_nnaquec": {
        "colun1": "motivacao-plac-nnaquec",
        "colun2": "motivacao-plac-aquec"
    },

    #preparacao
    "preparacao-cap_VS_plc_aquec": {
        "colun1": "preparacao-cap-aquec",
        "colun2": "preparacao-plac-aquec"
    },
    "preparacao-cap_VS_plc_nnaquec": {
        "colun1": "preparacao-cap-nnaquec",
        "colun2": "preparacao-plac-nnaquec"
    },
    "preparacao-cap_aquec_VS_cap_nnaquec": {
        "colun1": "preparacao-cap-nnaquec",
        "colun2": "preparacao-cap-aquec"
    },
    "preparacao-plc_aquec_VS_plc_nnaquec": {
        "colun1": "preparacao-plac-nnaquec",
        "colun2": "preparacao-plac-aquec"
    },

    #brums_fadiga
    "brums_fadiga-cap_VS_plc_aquec": {
        "colun1": "brums-fadiga-cap-aquec",
        "colun2": "brums-fadiga-plac-aquec"
    },
    "brums_fadiga-cap_VS_plc_nnaquec": {
        "colun1": "brums-fadiga-cap-nnaquec",
        "colun2": "brums-fadiga-plac-nnaquec"
    },
    "brums_fadiga-cap_aquec_VS_cap_nnaquec": {
        "colun1": "brums-fadiga-cap-nnaquec",
        "colun2": "brums-fadiga-cap-aquec"
    },
    "brums_fadiga-plc_aquec_VS_plc_nnaquec": {
        "colun1": "brums-fadiga-plac-nnaquec",
        "colun2": "brums-fadiga-plac-aquec"
    },


    #brums-vigor
    "brums-vigor-cap_VS_plc_aquec": {
        "colun1": "brums-vigor-cap-aquec",
        "colun2": "brums-vigor-plac-aquec"
    },
    "brums-vigor-cap_VS_plc_nnaquec": {
        "colun1": "brums-vigor-cap-nnaquec",
        "colun2": "brums-vigor-plac-nnaquec"
    },
    "brums-vigor-cap_aquec_VS_cap_nnaquec": {
        "colun1": "brums-vigor-cap-nnaquec",
        "colun2": "brums-vigor-cap-aquec"
    },
    "brums-vigor-plc_aquec_VS_plc_nnaquec": {
        "colun1": "brums-vigor-plac-nnaquec",
        "colun2": "brums-vigor-plac-aquec"
        }
}

# %%
#Altomatização do teste t restornando um DataFrame:

resultados = []

def test_t(colun1, colun2):
    values1 = df[colun1]
    values2 = df[colun2]
    stat, p = ttest_ind(values1.dropna(), values2.dropna())  # Remover valores NaN antes do teste
    classification = 'Diferença Significativa' if p < 0.05 else 'Diferença Não Significativa'


    resultado = { # Armazena os resultados em um dicionário
        'Coluna 1': colun1,
        'Coluna 2': colun2,
        'T-statistic': stat,
        'P-value': p,
        'Classificação': classification
    }

    resultados.append(resultado)  # Adiciona o dicionário à lista de resultados

for k, v in calculos_test_t.items(): # Executa os testes t e armazena os resultados
    colun1 = v["colun1"]
    colun2 = v["colun2"]
    test_t(colun1, colun2)


df_resultados = pd.DataFrame(resultados) # Converte a lista de resultados em um DataFrame

df_resultados.to_csv('teste_t_resultado.csv', index=True) # Salva o DataFrame em um arquivo CSV

print(df_resultados) # Exibe o DataFrame

# %%
#Altomatização do teste t sem salvar em DataFrame:

def test_t(colun1, colun2):
  values1 = df[colun1]
  values2 = df[colun2]
  stat, p = ttest_ind(values1.dropna(), values2.dropna())  # Remove valores NaN antes do teste
  if p < 0.05:# Classifica o valor de p
      classification = 'Diferença Significativa'
  else:
      classification = '**Diferença Não Significativa**'
  print(f'T-statistic: {stat}')# Imprimi os resultados
  print(f'P-value: {p}')
  print(f'Classificação: {classification}\n')

for k, v in calculos_test_t.items():
  print(k)
  colun1 = v["colun1"]
  colun2 = v["colun2"]
  test_t(colun1, colun2)
# Out:
# tempo-50m-cap_VS_plc_aquec
# T-statistic: -0.0065399591808050364
# P-value: 0.9948538427237397
# Classificação: **Diferença Não Significativa**
#
# tempo-50m-cap_VS_plc_nnaquec
# T-statistic: 0.0887722127282227
# P-value: 0.9302431849208908
# Classificação: **Diferença Não Significativa**
#
# tempo-50m-cap_aquec_VS_cap_nnaquec
# T-statistic: 0.13385621811380133
# P-value: 0.8950015214068723
# Classificação: **Diferença Não Significativa**
#
# tempo-50m-plc_aquec_VS_plc_nnaquec
# T-statistic: 0.040215356292345274
# P-value: 0.9683641390857578
# Classificação: **Diferença Não Significativa**
#
# tempo-15m-cap_VS_plc_aquec
# T-statistic: -0.059031387193322515
# P-value: 0.953577544286109
# Classificação: **Diferença Não Significativa**
#
# tempo-15m-cap_VS_plc_nnaquec
# T-statistic: -0.05797549967278393
# P-value: 0.9544069069603243
# Classificação: **Diferença Não Significativa**
#
# tempo-15m-cap_aquec_VS_cap_nnaquec
# T-statistic: -0.20614173745017042
# P-value: 0.8389938516707353
# Classificação: **Diferença Não Significativa**
#
# tempo-15m-plc_aquec_VS_plc_nnaquec
# T-statistic: -0.22524451451792932
# P-value: 0.8243265146413199
# Classificação: **Diferença Não Significativa**
#
# tempo-35m-cap_VS_plc_aquec
# T-statistic: 0.14145835787791242
# P-value: 0.8890790237012082
# Classificação: **Diferença Não Significativa**
#
# tempo-35m-cap_VS_plc_nnaquec
# T-statistic: 0.11781334249616984
# P-value: 0.9075202683161255
# Classificação: **Diferença Não Significativa**
#
# tempo-35m-cap_aquec_VS_cap_nnaquec
# T-statistic: 0.10576058588828886
# P-value: 0.9169420196555658
# Classificação: **Diferença Não Significativa**
#
# tempo-35m-plc_aquec_VS_plc_nnaquec
# T-statistic: 0.11709844559585444
# P-value: 0.908078730450725
# Classificação: **Diferença Não Significativa**
#
# lactato-pre-cap_VS_plc_aquec
# T-statistic: 0.13895717467849472
# P-value: 0.891026863569617
# Classificação: **Diferença Não Significativa**
#
# lactato-pre-cap_VS_plc_nnaquec
# T-statistic: -0.44584345258773994
# P-value: 0.6610266695329143
# Classificação: **Diferença Não Significativa**
#
# lactato-pre-cap_aquec_VS_cap_nnaquec
# T-statistic: -2.7385599923004236
# P-value: 0.013497637696749533
# Classificação: Diferença Significativa
#
# lactato-pre-plc_aquec_VS_plc_nnaquec
# T-statistic: -2.521032157790505
# P-value: 0.02135259815173636
# Classificação: Diferença Significativa
#
# lactato-pos_1min_cap_VS_plc_aquec
# T-statistic: -0.6205257117846685
# P-value: 0.5426894078068984
# Classificação: **Diferença Não Significativa**
#
# lactato-pos_1min_cap_VS_plc_nnaquec
# T-statistic: -0.818449326699178
# P-value: 0.4238039963728192
# Classificação: **Diferença Não Significativa**
#
# lactato-pos_1min_cap_aquec_VS_cap_nnaquec
# T-statistic: -2.0565721326404955
# P-value: 0.05452033888845643
# Classificação: **Diferença Não Significativa**
#
# lactato-pos_1min_plc_aquec_VS_plc_nnaquec
# T-statistic: -1.9390319632455888
# P-value: 0.06833772324880791
# Classificação: **Diferença Não Significativa**
#
# lactato-pos_3min_cap_VS_plc_aquec
# T-statistic: -0.6225895644919445
# P-value: 0.541362090115459
# Classificação: **Diferença Não Significativa**
#
# lactato-pos_3min_cap_VS_plc_nnaquec
# T-statistic: 0.1648897418870079
# P-value: 0.8708684038989436
# Classificação: **Diferença Não Significativa**
#
# lactato-pos_3min_cap_aquec_VS_cap_nnaquec
# T-statistic: -1.2154886358545238
# P-value: 0.2398821875210892
# Classificação: **Diferença Não Significativa**
#
# lactato-pos_3min_plc_aquec_VS_plc_nnaquec
# T-statistic: -1.7322243162903312
# P-value: 0.10033405889099718
# Classificação: **Diferença Não Significativa**
#
# scm-cap_VS_plc_aquec
# T-statistic: -0.04273990042080314
# P-value: 0.9663794164820878
# Classificação: **Diferença Não Significativa**
#
# scm-cap_VS_plc_nnaquec
# T-statistic: -0.658049785674056
# P-value: 0.5188344369315188
# Classificação: **Diferença Não Significativa**
#
# scm-cap_aquec_VS_cap_nnaquec
# T-statistic: 1.2862067060104456
# P-value: 0.21466993060233516
# Classificação: **Diferença Não Significativa**
#
# scm-plc_aquec_VS_plc_nnaquec
# T-statistic: 0.6757873312460397
# P-value: 0.5077658399152958
# Classificação: **Diferença Não Significativa**
#
# pse-cap_VS_plc_aquec
# T-statistic: -1.237705495510553
# P-value: 0.23172765994815903
# Classificação: **Diferença Não Significativa**
#
# pse-cap_VS_plc_nnaquec
# T-statistic: -0.6469966392206281
# P-value: 0.5257996995481655
# Classificação: **Diferença Não Significativa**
#
# pse-cap_aquec_VS_cap_nnaquec
# T-statistic: 0.5262348115842203
# P-value: 0.6051491952383768
# Classificação: **Diferença Não Significativa**
#
# pse-plc_aquec_VS_plc_nnaquec
# T-statistic: 0.0
# P-value: 1.0
# Classificação: **Diferença Não Significativa**
#
# motivacao-cap_VS_plc_aquec
# T-statistic: 0.7256412945149079
# P-value: 0.4773881028028454
# Classificação: **Diferença Não Significativa**
#
# motivacao-cap_VS_plc_nnaquec
# T-statistic: -0.3197188528905791
# P-value: 0.7528625714460355
# Classificação: **Diferença Não Significativa**
#
# motivacao-cap_aquec_VS_cap_nnaquec
# T-statistic: -0.4505677915691794
# P-value: 0.6576811677603291
# Classificação: **Diferença Não Significativa**
#
# motivacao-plc_aquec_VS_plc_nnaquec
# T-statistic: 0.6024046002179808
# P-value: 0.5544186759859844
# Classificação: **Diferença Não Significativa**
#
# preparacao-cap_VS_plc_aquec
# T-statistic: 0.30849365040815335
# P-value: 0.7612484876689731
# Classificação: **Diferença Não Significativa**
#
# preparacao-cap_VS_plc_nnaquec
# T-statistic: -0.2568089605062993
# P-value: 0.8002386970524972
# Classificação: **Diferença Não Significativa**
#
# preparacao-cap_aquec_VS_cap_nnaquec
# T-statistic: -0.3602917292253287
# P-value: 0.7228220725631596
# Classificação: **Diferença Não Significativa**
#
# preparacao-plc_aquec_VS_plc_nnaquec
# T-statistic: 0.20601796587971621
# P-value: 0.8390890894615036
# Classificação: **Diferença Não Significativa**
#
# brums_fadiga-cap_VS_plc_aquec
# T-statistic: -1.325250144120961
# P-value: 0.20166497016329124
# Classificação: **Diferença Não Significativa**
#
# brums_fadiga-cap_VS_plc_nnaquec
# T-statistic: 0.11504474832710566
# P-value: 0.9096833080137343
# Classificação: **Diferença Não Significativa**
#
# brums_fadiga-cap_aquec_VS_cap_nnaquec
# T-statistic: 2.3061611306751226
# P-value: 0.03321123644880426
# Classificação: Diferença Significativa
#
# brums_fadiga-plc_aquec_VS_plc_nnaquec
# T-statistic: 1.2727922061357857
# P-value: 0.21928669945211227
# Classificação: **Diferença Não Significativa**
#
# brums-vigor-cap_VS_plc_aquec
# T-statistic: 0.3624203517788945
# P-value: 0.7212582482661472
# Classificação: **Diferença Não Significativa**
#
# brums-vigor-cap_VS_plc_nnaquec
# T-statistic: -0.07256884707522872
# P-value: 0.9429495160257235
# Classificação: **Diferença Não Significativa**
#
# brums-vigor-cap_aquec_VS_cap_nnaquec
# T-statistic: -0.12356041264304264
# P-value: 0.9030326079461961
# Classificação: **Diferença Não Significativa**
#
# brums-vigor-plc_aquec_VS_plc_nnaquec
# T-statistic: 0.3678836036909799
# P-value: 0.7172503876906395
# Classificação: **Diferença Não Significativa**

# %%
# Tempo de 50 metros sem aquecimento
def wilcoxon_test(colun1, colun2):
    values1 = df[colun1]
    values2 = df[colun2]
    res = wilcoxon(values1.dropna(), values2.dropna())  # Remove valores NaN antes do teste
    if res.pvalue < 0.05:
        classification = 'Diferença Significativa'
    else:
        classification = 'Diferença Não Significativa'

    print(f'Estatística W: {res.statistic}')
    print(f'P-value: {res.pvalue}')
    print(f'Classificação: {classification}\n')

for k, v in calculos_test_t.items():
    print(k)
    colun1 = v["colun1"]
    colun2 = v["colun2"]
    wilcoxon_test(colun1, colun2)
# Out:
# tempo-50m-cap_VS_plc_aquec
# Estatística W: 24.0
# P-value: 0.76953125
# Classificação: Diferença Não Significativa
#
# tempo-50m-cap_VS_plc_nnaquec
# Estatística W: 10.5
# P-value: 0.15476920527702331
# Classificação: Diferença Não Significativa
#
# tempo-50m-cap_aquec_VS_cap_nnaquec
# Estatística W: 14.0
# P-value: 0.193359375
# Classificação: Diferença Não Significativa
#
# tempo-50m-plc_aquec_VS_plc_nnaquec
# Estatística W: 20.5
# P-value: 0.4921875
# Classificação: Diferença Não Significativa
#
# tempo-15m-cap_VS_plc_aquec
# Estatística W: 17.5
# P-value: 0.322265625
# Classificação: Diferença Não Significativa
#
# tempo-15m-cap_VS_plc_nnaquec
# Estatística W: 10.0
# P-value: 0.1372537974389985
# Classificação: Diferença Não Significativa
#
# tempo-15m-cap_aquec_VS_cap_nnaquec
# Estatística W: 22.5
# P-value: 1.0
# Classificação: Diferença Não Significativa
#
# tempo-15m-plc_aquec_VS_plc_nnaquec
# Estatística W: 16.0
# P-value: 0.44086703541808714
# Classificação: Diferença Não Significativa
#
# tempo-35m-cap_aquec_VS_plc_aquec
# Estatística W: 26.0
# P-value: 0.921875
# Classificação: Diferença Não Significativa
#
# tempo-35m-cap_nnaquec_VS_plc_nnaquec
# Estatística W: 1.0
# P-value: 0.046399461870904594
# Classificação: Diferença Significativa
#
# tempo-35m-cap_aquec_VS_cap_nnaquec
# Estatística W: 19.0
# P-value: 0.6784023758521882
# Classificação: Diferença Não Significativa
#
# tempo-35m-plc_aquec_VS_plc_nnaquec
# Estatística W: 9.0
# P-value: 0.7531523647659145
# Classificação: Diferença Não Significativa
#
# lactato-pre-cap_VS_plc_aquec
# Estatística W: 24.0
# P-value: 0.76953125
# Classificação: Diferença Não Significativa
#
# lactato-pre-cap_VS_plc_nnaquec
# Estatística W: 25.5
# P-value: 0.845703125
# Classificação: Diferença Não Significativa
#
# lactato-pre-cap_aquec_VS_cap_nnaquec
# Estatística W: 5.0
# P-value: 0.01953125
# Classificação: Diferença Significativa
#
# lactato-pre-plc_aquec_VS_plc_nnaquec
# Estatística W: 7.0
# P-value: 0.037109375
# Classificação: Diferença Significativa
#
# lactato-pos_1min_cap_VS_plc_aquec
# Estatística W: 18.0
# P-value: 0.375
# Classificação: Diferença Não Significativa
#
# lactato-pos_1min_cap_VS_plc_nnaquec
# Estatística W: 22.0
# P-value: 0.625
# Classificação: Diferença Não Significativa
#
# lactato-pos_1min_cap_aquec_VS_cap_nnaquec
# Estatística W: 10.0
# P-value: 0.083984375
# Classificação: Diferença Não Significativa
#
# lactato-pos_1min_plc_aquec_VS_plc_nnaquec
# Estatística W: 5.5
# P-value: 0.01953125
# Classificação: Diferença Significativa
#
# lactato-pos_3min_cap_VS_plc_aquec
# Estatística W: 15.0
# P-value: 0.232421875
# Classificação: Diferença Não Significativa
#
# lactato-pos_3min_cap_VS_plc_nnaquec
# Estatística W: 27.5
# P-value: 1.0
# Classificação: Diferença Não Significativa
#
# lactato-pos_3min_cap_aquec_VS_cap_nnaquec
# Estatística W: 12.0
# P-value: 0.130859375
# Classificação: Diferença Não Significativa
#
# lactato-pos_3min_plc_aquec_VS_plc_nnaquec
# Estatística W: 6.0
# P-value: 0.02734375
# Classificação: Diferença Significativa
#
# scm-cap_VS_plc_aquec
# Estatística W: 27.0
# P-value: 1.0
# Classificação: Diferença Não Significativa
#
# scm-cap_VS_plc_nnaquec
# Estatística W: 9.0
# P-value: 0.064453125
# Classificação: Diferença Não Significativa
#
# scm-cap_aquec_VS_cap_nnaquec
# Estatística W: 2.0
# P-value: 0.005859375
# Classificação: Diferença Significativa
#
# scm-plc_aquec_VS_plc_nnaquec
# Estatística W: 12.0
# P-value: 0.130859375
# Classificação: Diferença Não Significativa
#
# pse-cap_VS_plc_aquec
# Estatística W: 2.5
# P-value: 0.15729920705028516
# Classificação: Diferença Não Significativa
#
# pse-cap_VS_plc_nnaquec
# Estatística W: 1.5
# P-value: 0.4142161782425252
# Classificação: Diferença Não Significativa
#
# pse-cap_aquec_VS_cap_nnaquec
# Estatística W: 2.5
# P-value: 0.31731050786291415
# Classificação: Diferença Não Significativa
#
# pse-plc_aquec_VS_plc_nnaquec
# Estatística W: 1.5
# P-value: 1.0
# Classificação: Diferença Não Significativa
#
# motivacao-cap_VS_plc_aquec
# Estatística W: 5.5
# P-value: 0.02734375
# Classificação: Diferença Significativa
#
# motivacao-cap_VS_plc_nnaquec
# Estatística W: 19.5
# P-value: 0.431640625
# Classificação: Diferença Não Significativa
#
# motivacao-cap_aquec_VS_cap_nnaquec
# Estatística W: 10.0
# P-value: 0.083984375
# Classificação: Diferença Não Significativa
#
# motivacao-plc_aquec_VS_plc_nnaquec
# Estatística W: 15.0
# P-value: 0.6744240722352938
# Classificação: Diferença Não Significativa
#
# preparacao-cap_VS_plc_aquec
# Estatística W: 17.0
# P-value: 0.322265625
# Classificação: Diferença Não Significativa
#
# preparacao-cap_VS_plc_nnaquec
# Estatística W: 12.0
# P-value: 0.21272007128320014
# Classificação: Diferença Não Significativa
#
# preparacao-cap_aquec_VS_cap_nnaquec
# Estatística W: 10.5
# P-value: 0.083984375
# Classificação: Diferença Não Significativa
#
# preparacao-plc_aquec_VS_plc_nnaquec
# Estatística W: 23.0
# P-value: 0.6953125
# Classificação: Diferença Não Significativa
#
# brums_fadiga-cap_VS_plc_aquec
# Estatística W: 2.5
# P-value: 0.02778578270530869
# Classificação: Diferença Significativa
#
# brums_fadiga-cap_VS_plc_nnaquec
# Estatística W: 24.5
# P-value: 0.845703125
# Classificação: Diferença Não Significativa
#
# brums_fadiga-cap_aquec_VS_cap_nnaquec
# Estatística W: 3.5
# P-value: 0.041558707296959874
# Classificação: Diferença Significativa
#
# brums_fadiga-plc_aquec_VS_plc_nnaquec
# Estatística W: 9.5
# P-value: 0.23280433193453265
# Classificação: Diferença Não Significativa
#
# brums-vigor-cap_VS_plc_aquec
# Estatística W: 12.0
# P-value: 0.7257209852083116
# Classificação: Diferença Não Significativa
#
# brums-vigor-cap_VS_plc_nnaquec
# Estatística W: 10.5
# P-value: 1.0
# Classificação: Diferença Não Significativa
#
# brums-vigor-cap_aquec_VS_cap_nnaquec
# Estatística W: 10.0
# P-value: 0.9153452831107657
# Classificação: Diferença Não Significativa
#
# brums-vigor-plc_aquec_VS_plc_nnaquec
# Estatística W: 9.0
# P-value: 0.7388826803635273
# Classificação: Diferença Não Significativa

# %%
# Tempo 50 metros com aquecimento
tempo_50m_cap_aquec = df['tempo-50m-cap-aquec']
tempo_50m_plc_aquec = df['tempo-50m-plac-aquec']
tempo_50m_cap_aquec = tempo_50m_cap_aquec.dropna()# Remover valores NaN
tempo_50m_plc_aquec = tempo_50m_plc_aquec.dropna()

min_length = min(len(tempo_50m_cap_aquec), len(tempo_50m_plc_aquec)) # Verifica o comprimento mininmo
tempo_50m_cap_aquec = tempo_50m_cap_aquec[:min_length] # Ajusta o comprimento da coluna de acordo com o valor anterior
tempo_50m_plc_aquec = tempo_50m_plc_aquec[:min_length] # Ajusta o comprimento da coluna de acordo com o valor anterior

res = wilcoxon(tempo_50m_cap_aquec, tempo_50m_plc_aquec)
if res.pvalue < 0.05:
    classification = 'Diferença Significativa'
else:
    classification = 'Diferença Não Significativa'

# Retornar os resultados em um dicionário

result = { # Added a variable to store the results
    'Estatística W': res.statistic,
    'P-value': res.pvalue,
    'Classificação': classification
}
print(result) # Print the result
# Out:
# {'Estatística W': 24.0, 'P-value': 0.76953125, 'Classificação': 'Diferença Não Significativa'}

# %%
# Tempo de 15 metros com aquecimento

tempo_15m_cap_aquec = df['tempo-15m-cap-aquec']
tempo_15m_plc_aquec = df['tempo-15m-plac-aquec']
tempo_15m_cap_aquec = tempo_15m_cap_aquec.dropna()# Remover valores NaN
tempo_15m_plc_aquec = tempo_15m_plc_aquec.dropna()

min_length = min(len(tempo_15m_cap_aquec), len(tempo_15m_plc_aquec)) # Verifica o comprimento mininmo
tempo_15m_cap_aquec = tempo_15m_cap_aquec[:min_length] # Ajusta o comprimento da coluna de acordo com o valor anterior
tempo_15m_plc_aquec = tempo_15m_plc_aquec[:min_length] # Ajusta o comprimento da coluna de acordo com o valor anterior

res = wilcoxon(tempo_15m_cap_aquec, tempo_15m_plc_aquec)
if res.pvalue < 0.05:
    classification = 'Diferença Significativa'
else:
    classification = 'Diferença Não Significativa'

# Retornar os resultados em um dicionário

result = { # Added a variable to store the results
    'Estatística W': res.statistic,
    'P-value': res.pvalue,
    'Classificação': classification
}
print(result) # Print the result
# Out:
# {'Estatística W': 17.5, 'P-value': 0.322265625, 'Classificação': 'Diferença Não Significativa'}

# %%
# Tempo de 15 metros sem aquecimrento

tempo_15m_cap_nnaquec = df['tempo-15m-cap-nnaquec']
tempo_15m_plc_nnaquec = df['tempo-15m-plac-nnaquec']
tempo_15m_cap_nnaquec = tempo_15m_cap_nnaquec.dropna()# Remover valores NaN
tempo_15m_plc_nnaquec = tempo_15m_plc_nnaquec.dropna()

min_length = min(len(tempo_15m_cap_nnaquec), len(tempo_15m_plc_nnaquec)) # Verifica o comprimento mininmo
tempo_15m_cap_aquec = tempo_15m_cap_nnaquec[:min_length] # Ajusta o comprimento da coluna de acordo com o valor anterior
tempo_15m_plc_aquec = tempo_15m_plc_nnaquec[:min_length] # Ajusta o comprimento da coluna de acordo com o valor anterior

res = wilcoxon(tempo_15m_cap_nnaquec, tempo_15m_plc_nnaquec)
if res.pvalue < 0.05:
    classification = 'Diferença Significativa'
else:
    classification = 'Diferença Não Significativa'

# Retornar os resultados em um dicionário

result = { # Added a variable to store the results
    'Estatística W': res.statistic,
    'P-value': res.pvalue,
    'Classificação': classification
}
print(result) # Print the result
# Out:
# {'Estatística W': 10.0, 'P-value': 0.1372537974389985, 'Classificação': 'Diferença Não Significativa'}

# %%
# Tempo de 5 metros com aquecimento

tempo_35m_cap_aquec = df['tempo-35m-cap-aquec']
tempo_35m_plc_aquec = df['tempo-35m-plac-aquec']
tempo_35m_cap_aquec = tempo_35m_cap_aquec.dropna()# Remover valores NaN
tempo_35m_plc_aquec = tempo_35m_plc_aquec.dropna()

min_length = min(len(tempo_35m_cap_aquec), len(tempo_35m_plc_aquec)) # Verifica o comprimento mininmo
tempo_35m_cap_aquec = tempo_35m_cap_aquec[:min_length] # Ajusta o comprimento da coluna de acordo com o valor anterior
tempo_35m_plc_aquec = tempo_35m_plc_aquec[:min_length] # Ajusta o comprimento da coluna de acordo com o valor anterior

res = wilcoxon(tempo_35m_cap_aquec, tempo_35m_plc_aquec)
if res.pvalue < 0.05:
    classification = 'Diferença Significativa'
else:
    classification = 'Diferença Não Significativa'

# Retornar os resultados em um dicionário

result = { # Added a variable to store the results
    'Estatística W': res.statistic,
    'P-value': res.pvalue,
    'Classificação': classification
}
print(result) # Print the result
# Out:
# {'Estatística W': 26.0, 'P-value': 0.921875, 'Classificação': 'Diferença Não Significativa'}

# %%
# Tempo de 35 metros sem aquecimento

tempo_35m_cap_nnaquec = df['tempo-35m-cap-nnaquec']
tempo_35m_plc_nnaquec = df['tempo-35m-plac-nnaquec']
tempo_35m_cap_nnaquec = tempo_35m_cap_nnaquec.dropna()# Remover valores NaN
tempo_35m_plc_nnaquec = tempo_35m_plc_nnaquec.dropna()

min_length = min(len(tempo_35m_cap_nnaquec), len(tempo_35m_plc_nnaquec)) # Verifica o comprimento mininmo
tempo_35m_cap_nnaquec = tempo_35m_cap_nnaquec[:min_length] # Ajusta o comprimento da coluna de acordo com o valor anterior
tempo_35m_plc_nnaquec = tempo_35m_plc_nnaquec[:min_length] # Ajusta o comprimento da coluna de acordo com o valor anterior

res = wilcoxon(tempo_35m_cap_nnaquec, tempo_35m_plc_nnaquec)
if res.pvalue < 0.05:
    classification = 'Diferença Significativa'
else:
    classification = 'Diferença Não Significativa'

# Retornar os resultados em um dicionário

result = { # Added a variable to store the results
    'Estatística W': res.statistic,
    'P-value': res.pvalue,
    'Classificação': classification
}
print(result) # Print the result
# Out:
# {'Estatística W': 1.0, 'P-value': 0.046399461870904594, 'Classificação': 'Diferença Significativa'}

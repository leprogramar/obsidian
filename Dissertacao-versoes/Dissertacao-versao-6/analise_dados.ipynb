# %% [markdown]
# ## Importações

# %%
import pandas as pd
import numpy as np
from scipy.stats import shapiro #Teste de normalidade
from scipy.stats import ttest_ind #Teste t de Student
from scipy.stats import wilcoxon #Teste de Wilcoxon
from numpy import std, mean, sqrt #Para o teste de Cohen

# %% [markdown]
# ## Data Frame (df)

# %%
df = pd.read_csv('https://raw.githubusercontent.com/leprogramar/obsidian/master/Dissertacao-versoes/Dissertacao-versao-6/dados-filtrados-2.csv') # Esse Dataframe está hospedado no GitHub. Caso nao não carregue, procure pelo link.
#df = df.describe()
#pd.set_option('display.max_columns', None)
#df

# %% [markdown]
# # Teste automatizado de **Shapiro-Wilk** para todas as as variáveis

# %%
numeric_df = df.select_dtypes(include=['number']) # Filtrando para o spript pegar apenas dados numéricos
results = {}
for column in numeric_df.columns:
    stat, p = shapiro(numeric_df[column].dropna())  # Remover valores NaN antes do teste (o teste de shapiro dá erro se tiver Nan)
    results[column] = {'Statistic': stat, 'p_value': p}  # Armazenando os resultados em um dicionário
results_df = pd.DataFrame(results).T  # Convertendo o dicionário para um DataFrame
results_df['Teste de normalidade'] = results_df['p_value'].apply(lambda p: 'Normal' if p > 0.05 else 'Não normal') # Classificando o valor de p
results_df.to_csv('shapiro_results.csv', index=True)
print(results_df)
# Out:
#                             Statistic   p_value Teste de normalidade
# tempo-50m-cap-aquec          0.770920  0.006417           Não normal
# tempo-50m-plac-aquec         0.761119  0.004875           Não normal
# tempo-50m-cap-nnaquec        0.786787  0.010014           Não normal
# tempo-50m-plac-nnaquec       0.800984  0.014903           Não normal
# tempo-15m-cap-aquec          0.691617  0.000697           Não normal
# tempo-15m-plac-aquec         0.706765  0.001064           Não normal
# tempo-15m-cap-nnaquec        0.755062  0.004113           Não normal
# tempo-15m-plac-nnaquec       0.765936  0.005580           Não normal
# tempo-35m-cap-aquec          0.726346  0.001839           Não normal
# tempo-35m-plac-aquec         0.803666  0.016064           Não normal
# tempo-35m-cap-nnaquec        0.742681  0.002907           Não normal
# tempo-35m-plac-nnaquec       0.719463  0.001517           Não normal
# lac-pre-cap-aquec            0.931671  0.464532               Normal
# lac-pre-plac-aquec           0.941897  0.574304               Normal
# lac-pre-cap-nnaquec          0.903175  0.237317               Normal
# lac-pre-plac-nnaquec         0.837802  0.041526           Não normal
# lac-pos-1min-cap-aquec       0.905794  0.253334               Normal
# lac-pos-1min-plac-aquec      0.943887  0.597015               Normal
# lac-pos-1min-cap-nnaquec     0.849313  0.057005               Normal
# lac-pos-1min-plac-nnaquec    0.962504  0.814007               Normal
# lac-pos-3min-cap-aquec       0.913174  0.303511               Normal
# lac-pos-3min-plac-aquec      0.927276  0.421639               Normal
# lac-pos-3min-cap-nnaquec     0.932279  0.470682               Normal
# lac-pos-3min-plac-nnaquec    0.973799  0.923662               Normal
# pse-cap-aquec                0.805041  0.016694           Não normal
# pse-plac-aquec               0.655271  0.000254           Não normal
# pse-cap-nnaquec              0.780940  0.008500           Não normal
# pse-plac-nnaquec             0.655271  0.000254           Não normal
# altura-salto1-cap-aquec      0.958615  0.769977               Normal
# altura-salto2-cap-aquec      0.945220  0.612416               Normal
# altura-salto3-cap-aquec      0.934330  0.491805               Normal
# media-salto-cap-aquec        0.949782  0.665918               Normal
# altura-salto1-plac-aquec     0.942955  0.586344               Normal
# altura-salto2-plac-aquec     0.927787  0.426477               Normal
# altura-salto3-plac-aquec     0.913415  0.305283               Normal
# media-salto-plac-aquec       0.963477  0.824674               Normal
# altura-salto1-cap-nnaquec    0.915392  0.320120               Normal
# altura-salto2-cap-nnaquec    0.935453  0.503613               Normal
# altura-salto3-cap-nnaquec    0.956235  0.742236               Normal
# media-salto-cap-nnaquec      0.927769  0.426309               Normal
# altura-salto1-plac-nnaquec   0.949949  0.667895               Normal
# altura-salto2-plac-nnaquec   0.927655  0.425228               Normal
# altura-salto3-plac-nnaquec   0.964728  0.838137               Normal
# media-salto-plac-nnaquec     0.940562  0.559287               Normal
# motivacao-cap-aquec          0.887145  0.157438               Normal
# motivacao-plac-aquec         0.897317  0.204674               Normal
# motivacao-cap-nnaquec        0.902627  0.234080               Normal
# motivacao-plac-nnaquec       0.945940  0.620779               Normal
# preparacao-cap-aquec         0.906083  0.255153               Normal
# preparacao-plac-aquec        0.852575  0.062330               Normal
# preparacao-cap-nnaquec       0.853934  0.064689               Normal
# preparacao-plac-nnaquec      0.850362  0.058669               Normal
# brums-vigor-cap-aquec        0.940587  0.559565               Normal
# brums-vigor-plac-aquec       0.897348  0.204834               Normal
# brums-vigor-cap-nnaquec      0.905641  0.252373               Normal
# brums-vigor-plac-nnaquec     0.915880  0.323873               Normal
# brums-fadiga-cap-aquec       0.843602  0.048728           Não normal
# brums-fadiga-plac-aquec      0.879948  0.130315               Normal
# brums-fadiga-cap-nnaquec     0.870983  0.102637               Normal
# brums-fadiga-plac-nnaquec    0.969915  0.890053               Normal

# %% [markdown]
# ## Dicionário de variáveis

# %%
# Dicionário de variáveis:

calculos_test_t = {
    #Tempo 50 metros
    "tempo-50m-cap_VS_plc_aquec": {
        "colun1": "tempo-50m-cap-aquec",
        "colun2": "tempo-50m-plac-aquec"
    },
    "tempo-50m-cap_VS_plc_nnaquec": {
        "colun1": "tempo-50m-cap-nnaquec",
        "colun2": "tempo-50m-plac-nnaquec"
    },
    "tempo-50m-cap_aquec_VS_cap_nnaquec": {
        "colun1": "tempo-50m-cap-nnaquec",
        "colun2": "tempo-50m-cap-aquec"
    },
    "tempo-50m-plc_aquec_VS_plc_nnaquec": {
        "colun1": "tempo-50m-plac-nnaquec",
        "colun2": "tempo-50m-plac-aquec"
    },

    #Tempo 15 metros
        "tempo-15m-cap_VS_plc_aquec": {
        "colun1": "tempo-15m-cap-aquec",
        "colun2": "tempo-15m-plac-aquec"
    },
    "tempo-15m-cap_VS_plc_nnaquec": {
        "colun1": "tempo-15m-cap-nnaquec",
        "colun2": "tempo-15m-plac-nnaquec"
    },
    "tempo-15m-cap_aquec_VS_cap_nnaquec": {
        "colun1": "tempo-15m-cap-nnaquec",
        "colun2": "tempo-15m-cap-aquec"
    },
    "tempo-15m-plc_aquec_VS_plc_nnaquec": {
        "colun1": "tempo-15m-plac-nnaquec",
        "colun2": "tempo-15m-plac-aquec"
    },


    #Tempo 35 metros
    "tempo-35m-cap_aquec_VS_plc_aquec": {
        "colun1": "tempo-35m-cap-aquec",
        "colun2": "tempo-35m-plac-aquec"
    },
    "tempo-35m-cap_nnaquec_VS_plc_nnaquec": {
        "colun1": "tempo-35m-cap-nnaquec",
        "colun2": "tempo-35m-plac-nnaquec"
    },
    "tempo-35m-cap_aquec_VS_cap_nnaquec": {
        "colun1": "tempo-35m-cap-nnaquec",
        "colun2": "tempo-35m-cap-aquec"
    },
    "tempo-35m-plc_aquec_VS_plc_nnaquec": {
        "colun1": "tempo-35m-plac-nnaquec",
        "colun2": "tempo-35m-plac-aquec"
    },

    #Lactato pré
    "lactato-pre-cap_VS_plc_aquec": {
        "colun1": "lac-pre-cap-aquec",
        "colun2": "lac-pre-plac-aquec"
    },
    "lactato-pre-cap_VS_plc_nnaquec": {
        "colun1": "lac-pre-cap-nnaquec",
        "colun2": "lac-pre-plac-nnaquec"
    },
    "lactato-pre-cap_aquec_VS_cap_nnaquec": {
        "colun1": "lac-pre-cap-nnaquec",
        "colun2": "lac-pre-cap-aquec"
    },
    "lactato-pre-plc_aquec_VS_plc_nnaquec": {
        "colun1": "lac-pre-plac-nnaquec",
        "colun2": "lac-pre-plac-aquec"
    },
    #Lactato pós 1 min
    "lactato-pos_1min_cap_VS_plc_aquec": {
        "colun1": "lac-pos-1min-cap-aquec",
        "colun2": "lac-pos-1min-plac-aquec"
    },
    "lactato-pos_1min_cap_VS_plc_nnaquec": {
        "colun1": "lac-pos-1min-cap-nnaquec",
        "colun2": "lac-pos-1min-plac-nnaquec"
    },
    "lactato-pos_1min_cap_aquec_VS_cap_nnaquec": {
        "colun1": "lac-pos-1min-cap-nnaquec",
        "colun2": "lac-pos-1min-cap-aquec"
    },
    "lactato-pos_1min_plc_aquec_VS_plc_nnaquec": {
        "colun1": "lac-pos-1min-plac-nnaquec",
        "colun2": "lac-pos-1min-plac-aquec"
    },

    #Lactato pos 3 min
        "lactato-pos_3min_cap_VS_plc_aquec": {
        "colun1": "lac-pos-3min-cap-aquec",
        "colun2": "lac-pos-3min-plac-aquec"
    },
    "lactato-pos_3min_cap_VS_plc_nnaquec": {
        "colun1": "lac-pos-3min-cap-nnaquec",
        "colun2": "lac-pos-3min-plac-nnaquec"
    },
    "lactato-pos_3min_cap_aquec_VS_cap_nnaquec": {
        "colun1": "lac-pos-3min-cap-nnaquec",
        "colun2": "lac-pos-3min-cap-aquec"
    },
    "lactato-pos_3min_plc_aquec_VS_plc_nnaquec": {
        "colun1": "lac-pos-3min-plac-nnaquec",
        "colun2": "lac-pos-3min-plac-aquec"
    },

    #SCM
    "scm-cap_VS_plc_aquec": {
        "colun1": "media-salto-cap-aquec",
        "colun2": "media-salto-plac-aquec"
    },
    "scm-cap_VS_plc_nnaquec": {
        "colun1": "media-salto-cap-nnaquec",
        "colun2": "media-salto-plac-nnaquec"
    },
    "scm-cap_aquec_VS_cap_nnaquec": {
        "colun1": "media-salto-cap-aquec",
        "colun2": "media-salto-cap-nnaquec"
    },
    "scm-plc_aquec_VS_plc_nnaquec": {
        "colun1": "media-salto-plac-aquec",
        "colun2": "media-salto-plac-nnaquec"
    },

    #pse
    "pse-cap_VS_plc_aquec": {
        "colun1": "pse-cap-aquec",
        "colun2": "pse-plac-aquec"
    },
    "pse-cap_VS_plc_nnaquec": {
        "colun1": "pse-cap-nnaquec",
        "colun2": "pse-plac-nnaquec"
    },
    "pse-cap_aquec_VS_cap_nnaquec": {
        "colun1": "pse-cap-nnaquec",
        "colun2": "pse-cap-aquec"
    },
    "pse-plc_aquec_VS_plc_nnaquec": {
        "colun1": "pse-plac-nnaquec",
        "colun2": "pse-plac-aquec"
    },

    #motivacao
    "motivacao-cap_VS_plc_aquec": {
        "colun1": "motivacao-cap-aquec",
        "colun2": "motivacao-plac-aquec"
    },
    "motivacao-cap_VS_plc_nnaquec": {
        "colun1": "motivacao-cap-nnaquec",
        "colun2": "motivacao-plac-nnaquec"
    },
    "motivacao-cap_aquec_VS_cap_nnaquec": {
        "colun1": "motivacao-cap-nnaquec",
        "colun2": "motivacao-cap-aquec"
    },
    "motivacao-plc_aquec_VS_plc_nnaquec": {
        "colun1": "motivacao-plac-nnaquec",
        "colun2": "motivacao-plac-aquec"
    },

    #preparacao
    "preparacao-cap_VS_plc_aquec": {
        "colun1": "preparacao-cap-aquec",
        "colun2": "preparacao-plac-aquec"
    },
    "preparacao-cap_VS_plc_nnaquec": {
        "colun1": "preparacao-cap-nnaquec",
        "colun2": "preparacao-plac-nnaquec"
    },
    "preparacao-cap_aquec_VS_cap_nnaquec": {
        "colun1": "preparacao-cap-nnaquec",
        "colun2": "preparacao-cap-aquec"
    },
    "preparacao-plc_aquec_VS_plc_nnaquec": {
        "colun1": "preparacao-plac-nnaquec",
        "colun2": "preparacao-plac-aquec"
    },

    #brums_fadiga
    "brums_fadiga-cap_VS_plc_aquec": {
        "colun1": "brums-fadiga-cap-aquec",
        "colun2": "brums-fadiga-plac-aquec"
    },
    "brums_fadiga-cap_VS_plc_nnaquec": {
        "colun1": "brums-fadiga-cap-nnaquec",
        "colun2": "brums-fadiga-plac-nnaquec"
    },
    "brums_fadiga-cap_aquec_VS_cap_nnaquec": {
        "colun1": "brums-fadiga-cap-nnaquec",
        "colun2": "brums-fadiga-cap-aquec"
    },
    "brums_fadiga-plc_aquec_VS_plc_nnaquec": {
        "colun1": "brums-fadiga-plac-nnaquec",
        "colun2": "brums-fadiga-plac-aquec"
    },


    #brums-vigor
    "brums-vigor-cap_VS_plc_aquec": {
        "colun1": "brums-vigor-cap-aquec",
        "colun2": "brums-vigor-plac-aquec"
    },
    "brums-vigor-cap_VS_plc_nnaquec": {
        "colun1": "brums-vigor-cap-nnaquec",
        "colun2": "brums-vigor-plac-nnaquec"
    },
    "brums-vigor-cap_aquec_VS_cap_nnaquec": {
        "colun1": "brums-vigor-cap-nnaquec",
        "colun2": "brums-vigor-cap-aquec"
    },
    "brums-vigor-plc_aquec_VS_plc_nnaquec": {
        "colun1": "brums-vigor-plac-nnaquec",
        "colun2": "brums-vigor-plac-aquec"
        }
}

# %% [markdown]
# ### **Teste de Hipótese**
#
# 1. Para variáveis com distribuição normal, foi realizado o teste **t de Student**.
# 2. Para variáveis com distribuição não normal, foi adotado o teste **de Wilcoxon**.
# 3. Para todos os testes, a hipótese nula (H0) foi rejeitada se \( p < 0,05 \).

# %% [markdown]
# ## **Teste-t de Sudent** automatizado

# %%
#Automatização do teste t restornando um DataFrame:

resultados = []

def test_t(colun1, colun2):
    values1 = df[colun1]
    values2 = df[colun2]
    stat, p = ttest_ind(values1.dropna(), values2.dropna())  # Remover valores NaN antes do teste
    classification = 'Diferença Significativa' if p < 0.05 else 'Diferença Não Significativa'


    resultado = { # Armazena os resultados em um dicionário
        'Coluna 1': colun1,
        'Coluna 2': colun2,
        'T-statistic': stat,
        'P-value': p,
        'Classificação': classification
    }

    resultados.append(resultado)  # Adiciona o dicionário à lista de resultados

for k, v in calculos_test_t.items(): # Executa os testes t e armazena os resultados
    colun1 = v["colun1"]
    colun2 = v["colun2"]
    test_t(colun1, colun2)


df_resultados = pd.DataFrame(resultados) # Converte a lista de resultados em um DataFrame

df_resultados.to_csv('teste_t_resultado.csv', index=True) # Salva o DataFrame em um arquivo CSV

print(df_resultados) # Exibe o DataFrame
# Out:
#                      Coluna 1                   Coluna 2  T-statistic  \
# 0         tempo-50m-cap-aquec       tempo-50m-plac-aquec    -0.006540
# 1       tempo-50m-cap-nnaquec     tempo-50m-plac-nnaquec     0.088772
# 2       tempo-50m-cap-nnaquec        tempo-50m-cap-aquec     0.133856
# 3      tempo-50m-plac-nnaquec       tempo-50m-plac-aquec     0.040215
# 4         tempo-15m-cap-aquec       tempo-15m-plac-aquec    -0.059031
# 5       tempo-15m-cap-nnaquec     tempo-15m-plac-nnaquec    -0.057975
# 6       tempo-15m-cap-nnaquec        tempo-15m-cap-aquec    -0.206142
# 7      tempo-15m-plac-nnaquec       tempo-15m-plac-aquec    -0.225245
# 8         tempo-35m-cap-aquec       tempo-35m-plac-aquec     0.141458
# 9       tempo-35m-cap-nnaquec     tempo-35m-plac-nnaquec     0.117813
# 10      tempo-35m-cap-nnaquec        tempo-35m-cap-aquec     0.105761
# 11     tempo-35m-plac-nnaquec       tempo-35m-plac-aquec     0.117098
# 12          lac-pre-cap-aquec         lac-pre-plac-aquec     0.138957
# 13        lac-pre-cap-nnaquec       lac-pre-plac-nnaquec    -0.445843
# 14        lac-pre-cap-nnaquec          lac-pre-cap-aquec    -2.738560
# 15       lac-pre-plac-nnaquec         lac-pre-plac-aquec    -2.521032
# 16     lac-pos-1min-cap-aquec    lac-pos-1min-plac-aquec    -0.620526
# 17   lac-pos-1min-cap-nnaquec  lac-pos-1min-plac-nnaquec    -0.818449
# 18   lac-pos-1min-cap-nnaquec     lac-pos-1min-cap-aquec    -2.056572
# 19  lac-pos-1min-plac-nnaquec    lac-pos-1min-plac-aquec    -1.939032
# 20     lac-pos-3min-cap-aquec    lac-pos-3min-plac-aquec    -0.622590
# 21   lac-pos-3min-cap-nnaquec  lac-pos-3min-plac-nnaquec     0.164890
# 22   lac-pos-3min-cap-nnaquec     lac-pos-3min-cap-aquec    -1.215489
# 23  lac-pos-3min-plac-nnaquec    lac-pos-3min-plac-aquec    -1.732224
# 24      media-salto-cap-aquec     media-salto-plac-aquec    -0.042740
# 25    media-salto-cap-nnaquec   media-salto-plac-nnaquec    -0.658050
# 26      media-salto-cap-aquec    media-salto-cap-nnaquec     1.286207
# 27     media-salto-plac-aquec   media-salto-plac-nnaquec     0.675787
# 28              pse-cap-aquec             pse-plac-aquec    -1.237705
# 29            pse-cap-nnaquec           pse-plac-nnaquec    -0.646997
# 30            pse-cap-nnaquec              pse-cap-aquec     0.526235
# 31           pse-plac-nnaquec             pse-plac-aquec     0.000000
# 32        motivacao-cap-aquec       motivacao-plac-aquec     0.725641
# 33      motivacao-cap-nnaquec     motivacao-plac-nnaquec    -0.319719
# 34      motivacao-cap-nnaquec        motivacao-cap-aquec    -0.450568
# 35     motivacao-plac-nnaquec       motivacao-plac-aquec     0.602405
# 36       preparacao-cap-aquec      preparacao-plac-aquec     0.308494
# 37     preparacao-cap-nnaquec    preparacao-plac-nnaquec    -0.256809
# 38     preparacao-cap-nnaquec       preparacao-cap-aquec    -0.360292
# 39    preparacao-plac-nnaquec      preparacao-plac-aquec     0.206018
# 40     brums-fadiga-cap-aquec    brums-fadiga-plac-aquec    -1.325250
# 41   brums-fadiga-cap-nnaquec  brums-fadiga-plac-nnaquec     0.115045
# 42   brums-fadiga-cap-nnaquec     brums-fadiga-cap-aquec     2.306161
# 43  brums-fadiga-plac-nnaquec    brums-fadiga-plac-aquec     1.272792
# 44      brums-vigor-cap-aquec     brums-vigor-plac-aquec     0.362420
# 45    brums-vigor-cap-nnaquec   brums-vigor-plac-nnaquec    -0.072569
# 46    brums-vigor-cap-nnaquec      brums-vigor-cap-aquec    -0.123560
# 47   brums-vigor-plac-nnaquec     brums-vigor-plac-aquec     0.367884
#
#      P-value                Classificação
# 0   0.994854  Diferença Não Significativa
# 1   0.930243  Diferença Não Significativa
# 2   0.895002  Diferença Não Significativa
# 3   0.968364  Diferença Não Significativa
# 4   0.953578  Diferença Não Significativa
# 5   0.954407  Diferença Não Significativa
# 6   0.838994  Diferença Não Significativa
# 7   0.824327  Diferença Não Significativa
# 8   0.889079  Diferença Não Significativa
# 9   0.907520  Diferença Não Significativa
# 10  0.916942  Diferença Não Significativa
# 11  0.908079  Diferença Não Significativa
# 12  0.891027  Diferença Não Significativa
# 13  0.661027  Diferença Não Significativa
# 14  0.013498      Diferença Significativa
# 15  0.021353      Diferença Significativa
# 16  0.542689  Diferença Não Significativa
# 17  0.423804  Diferença Não Significativa
# 18  0.054520  Diferença Não Significativa
# 19  0.068338  Diferença Não Significativa
# 20  0.541362  Diferença Não Significativa
# 21  0.870868  Diferença Não Significativa
# 22  0.239882  Diferença Não Significativa
# 23  0.100334  Diferença Não Significativa
# 24  0.966379  Diferença Não Significativa
# 25  0.518834  Diferença Não Significativa
# 26  0.214670  Diferença Não Significativa
# 27  0.507766  Diferença Não Significativa
# 28  0.231728  Diferença Não Significativa
# 29  0.525800  Diferença Não Significativa
# 30  0.605149  Diferença Não Significativa
# 31  1.000000  Diferença Não Significativa
# 32  0.477388  Diferença Não Significativa
# 33  0.752863  Diferença Não Significativa
# 34  0.657681  Diferença Não Significativa
# 35  0.554419  Diferença Não Significativa
# 36  0.761248  Diferença Não Significativa
# 37  0.800239  Diferença Não Significativa
# 38  0.722822  Diferença Não Significativa
# 39  0.839089  Diferença Não Significativa
# 40  0.201665  Diferença Não Significativa
# 41  0.909683  Diferença Não Significativa
# 42  0.033211      Diferença Significativa
# 43  0.219287  Diferença Não Significativa
# 44  0.721258  Diferença Não Significativa
# 45  0.942950  Diferença Não Significativa
# 46  0.903033  Diferença Não Significativa
# 47  0.717250  Diferença Não Significativa

# %% [markdown]
# ## Teste de **Wilcoxon** automatizado

# %%
# Teste de Wilcoxon automatizado gerarando DataFrame

resultados = []
def wilcoxon_test(colun1, colun2):
    values1 = df[colun1]
    values2 = df[colun2]
    res = wilcoxon(values1.dropna(), values2.dropna())  # Remove valores NaN antes do teste
    if res.pvalue < 0.05:
        classification = 'Diferença Significativa'
    else:
        classification = 'Diferença Não Significativa'

    resultado = { # Armazena os resultados em um dicionário
        'Coluna 1': colun1,
        'Coluna 2': colun2,
        'Estatística W': res.statistic,
        'P-value': res.pvalue,
        'Classificação': classification
    }

    resultados.append(resultado)  # Adiciona o dicionário à lista de resultados

for k, v in calculos_test_t.items():
    print(k)
    colun1 = v["colun1"]
    colun2 = v["colun2"]
    wilcoxon_test(colun1, colun2)


df_resultados = pd.DataFrame(resultados) # Converte a lista de resultados em um DataFrame

df_resultados.to_csv('wilcoxon_test_resultado.csv', index=True) # Salva o DataFrame em um arquivo CSV

print(df_resultados) # Exibe o DataFrame
# Out:
# tempo-50m-cap_VS_plc_aquec
# tempo-50m-cap_VS_plc_nnaquec
# tempo-50m-cap_aquec_VS_cap_nnaquec
# tempo-50m-plc_aquec_VS_plc_nnaquec
# tempo-15m-cap_VS_plc_aquec
# tempo-15m-cap_VS_plc_nnaquec
# tempo-15m-cap_aquec_VS_cap_nnaquec
# tempo-15m-plc_aquec_VS_plc_nnaquec
# tempo-35m-cap_aquec_VS_plc_aquec
# tempo-35m-cap_nnaquec_VS_plc_nnaquec
# tempo-35m-cap_aquec_VS_cap_nnaquec
# tempo-35m-plc_aquec_VS_plc_nnaquec
# lactato-pre-cap_VS_plc_aquec
# lactato-pre-cap_VS_plc_nnaquec
# lactato-pre-cap_aquec_VS_cap_nnaquec
# lactato-pre-plc_aquec_VS_plc_nnaquec
# lactato-pos_1min_cap_VS_plc_aquec
# lactato-pos_1min_cap_VS_plc_nnaquec
# lactato-pos_1min_cap_aquec_VS_cap_nnaquec
# lactato-pos_1min_plc_aquec_VS_plc_nnaquec
# lactato-pos_3min_cap_VS_plc_aquec
# lactato-pos_3min_cap_VS_plc_nnaquec
# lactato-pos_3min_cap_aquec_VS_cap_nnaquec
# lactato-pos_3min_plc_aquec_VS_plc_nnaquec
# scm-cap_VS_plc_aquec
# scm-cap_VS_plc_nnaquec
# scm-cap_aquec_VS_cap_nnaquec
# scm-plc_aquec_VS_plc_nnaquec
# pse-cap_VS_plc_aquec
# pse-cap_VS_plc_nnaquec
# pse-cap_aquec_VS_cap_nnaquec
# pse-plc_aquec_VS_plc_nnaquec
# motivacao-cap_VS_plc_aquec
# motivacao-cap_VS_plc_nnaquec
# motivacao-cap_aquec_VS_cap_nnaquec
# motivacao-plc_aquec_VS_plc_nnaquec
# preparacao-cap_VS_plc_aquec
# preparacao-cap_VS_plc_nnaquec
# preparacao-cap_aquec_VS_cap_nnaquec
# preparacao-plc_aquec_VS_plc_nnaquec
# brums_fadiga-cap_VS_plc_aquec
# brums_fadiga-cap_VS_plc_nnaquec
# brums_fadiga-cap_aquec_VS_cap_nnaquec
# brums_fadiga-plc_aquec_VS_plc_nnaquec
# brums-vigor-cap_VS_plc_aquec
# brums-vigor-cap_VS_plc_nnaquec
# brums-vigor-cap_aquec_VS_cap_nnaquec
# brums-vigor-plc_aquec_VS_plc_nnaquec
#                      Coluna 1                   Coluna 2  Estatística W  \
# 0         tempo-50m-cap-aquec       tempo-50m-plac-aquec           24.0
# 1       tempo-50m-cap-nnaquec     tempo-50m-plac-nnaquec           10.5
# 2       tempo-50m-cap-nnaquec        tempo-50m-cap-aquec           14.0
# 3      tempo-50m-plac-nnaquec       tempo-50m-plac-aquec           20.5
# 4         tempo-15m-cap-aquec       tempo-15m-plac-aquec           17.5
# 5       tempo-15m-cap-nnaquec     tempo-15m-plac-nnaquec           10.0
# 6       tempo-15m-cap-nnaquec        tempo-15m-cap-aquec           22.5
# 7      tempo-15m-plac-nnaquec       tempo-15m-plac-aquec           16.0
# 8         tempo-35m-cap-aquec       tempo-35m-plac-aquec           26.0
# 9       tempo-35m-cap-nnaquec     tempo-35m-plac-nnaquec            1.0
# 10      tempo-35m-cap-nnaquec        tempo-35m-cap-aquec           19.0
# 11     tempo-35m-plac-nnaquec       tempo-35m-plac-aquec            9.0
# 12          lac-pre-cap-aquec         lac-pre-plac-aquec           24.0
# 13        lac-pre-cap-nnaquec       lac-pre-plac-nnaquec           25.5
# 14        lac-pre-cap-nnaquec          lac-pre-cap-aquec            5.0
# 15       lac-pre-plac-nnaquec         lac-pre-plac-aquec            7.0
# 16     lac-pos-1min-cap-aquec    lac-pos-1min-plac-aquec           18.0
# 17   lac-pos-1min-cap-nnaquec  lac-pos-1min-plac-nnaquec           22.0
# 18   lac-pos-1min-cap-nnaquec     lac-pos-1min-cap-aquec           10.0
# 19  lac-pos-1min-plac-nnaquec    lac-pos-1min-plac-aquec            5.5
# 20     lac-pos-3min-cap-aquec    lac-pos-3min-plac-aquec           15.0
# 21   lac-pos-3min-cap-nnaquec  lac-pos-3min-plac-nnaquec           27.5
# 22   lac-pos-3min-cap-nnaquec     lac-pos-3min-cap-aquec           12.0
# 23  lac-pos-3min-plac-nnaquec    lac-pos-3min-plac-aquec            6.0
# 24      media-salto-cap-aquec     media-salto-plac-aquec           27.0
# 25    media-salto-cap-nnaquec   media-salto-plac-nnaquec            9.0
# 26      media-salto-cap-aquec    media-salto-cap-nnaquec            2.0
# 27     media-salto-plac-aquec   media-salto-plac-nnaquec           12.0
# 28              pse-cap-aquec             pse-plac-aquec            2.5
# 29            pse-cap-nnaquec           pse-plac-nnaquec            1.5
# 30            pse-cap-nnaquec              pse-cap-aquec            2.5
# 31           pse-plac-nnaquec             pse-plac-aquec            1.5
# 32        motivacao-cap-aquec       motivacao-plac-aquec            5.5
# 33      motivacao-cap-nnaquec     motivacao-plac-nnaquec           19.5
# 34      motivacao-cap-nnaquec        motivacao-cap-aquec           10.0
# 35     motivacao-plac-nnaquec       motivacao-plac-aquec           15.0
# 36       preparacao-cap-aquec      preparacao-plac-aquec           17.0
# 37     preparacao-cap-nnaquec    preparacao-plac-nnaquec           12.0
# 38     preparacao-cap-nnaquec       preparacao-cap-aquec           10.5
# 39    preparacao-plac-nnaquec      preparacao-plac-aquec           23.0
# 40     brums-fadiga-cap-aquec    brums-fadiga-plac-aquec            2.5
# 41   brums-fadiga-cap-nnaquec  brums-fadiga-plac-nnaquec           24.5
# 42   brums-fadiga-cap-nnaquec     brums-fadiga-cap-aquec            3.5
# 43  brums-fadiga-plac-nnaquec    brums-fadiga-plac-aquec            9.5
# 44      brums-vigor-cap-aquec     brums-vigor-plac-aquec           12.0
# 45    brums-vigor-cap-nnaquec   brums-vigor-plac-nnaquec           10.5
# 46    brums-vigor-cap-nnaquec      brums-vigor-cap-aquec           10.0
# 47   brums-vigor-plac-nnaquec     brums-vigor-plac-aquec            9.0
#
#      P-value                Classificação
# 0   0.769531  Diferença Não Significativa
# 1   0.154769  Diferença Não Significativa
# 2   0.193359  Diferença Não Significativa
# 3   0.492188  Diferença Não Significativa
# 4   0.322266  Diferença Não Significativa
# 5   0.137254  Diferença Não Significativa
# 6   1.000000  Diferença Não Significativa
# 7   0.440867  Diferença Não Significativa
# 8   0.921875  Diferença Não Significativa
# 9   0.046399      Diferença Significativa
# 10  0.678402  Diferença Não Significativa
# 11  0.753152  Diferença Não Significativa
# 12  0.769531  Diferença Não Significativa
# 13  0.845703  Diferença Não Significativa
# 14  0.019531      Diferença Significativa
# 15  0.037109      Diferença Significativa
# 16  0.375000  Diferença Não Significativa
# 17  0.625000  Diferença Não Significativa
# 18  0.083984  Diferença Não Significativa
# 19  0.019531      Diferença Significativa
# 20  0.232422  Diferença Não Significativa
# 21  1.000000  Diferença Não Significativa
# 22  0.130859  Diferença Não Significativa
# 23  0.027344      Diferença Significativa
# 24  1.000000  Diferença Não Significativa
# 25  0.064453  Diferença Não Significativa
# 26  0.005859      Diferença Significativa
# 27  0.130859  Diferença Não Significativa
# 28  0.157299  Diferença Não Significativa
# 29  0.414216  Diferença Não Significativa
# 30  0.317311  Diferença Não Significativa
# 31  1.000000  Diferença Não Significativa
# 32  0.027344      Diferença Significativa
# 33  0.431641  Diferença Não Significativa
# 34  0.083984  Diferença Não Significativa
# 35  0.674424  Diferença Não Significativa
# 36  0.322266  Diferença Não Significativa
# 37  0.212720  Diferença Não Significativa
# 38  0.083984  Diferença Não Significativa
# 39  0.695312  Diferença Não Significativa
# 40  0.027786      Diferença Significativa
# 41  0.845703  Diferença Não Significativa
# 42  0.041559      Diferença Significativa
# 43  0.232804  Diferença Não Significativa
# 44  0.725721  Diferença Não Significativa
# 45  1.000000  Diferença Não Significativa
# 46  0.915345  Diferença Não Significativa
# 47  0.738883  Diferença Não Significativa
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_morestats.py:4088: UserWarning: Exact p-value calculation does not work if there are zeros. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_morestats.py:4102: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")

# %% [markdown]
# ## Teste D de Cohen para todas as variáveis

# %%
# Teste d de Cohen

import pandas as pd
def cohen_d(x,y):
  nx = len(x)
  ny = len(y)
  dof = nx + ny - 2
  return (mean(x) - mean(y)) / sqrt(((nx-1)*std(x, ddof=1) ** 2 + (ny-1)*std(y, ddof=1) ** 2) / dof)

resultados_d_cohen = []
for k, v in calculos_test_t.items():
  coluna1 = v["colun1"]
  coluna2 = v["colun2"]
  valores1 = df[coluna1].dropna()
  valores2 = df[coluna2].dropna()
  d = cohen_d(valores1, valores2)
  tamanho_efeito = ''
  if abs(d) < 0.2:
    tamanho_efeito = 'Pequeno'
  elif abs(d) < 0.5:
    tamanho_efeito = 'Médio'
  else:
    tamanho_efeito = 'Grande'

  resultados_d_cohen.append({
      'Comparação': k,
      'Cohen\'s d': d,
      'Tamanho do Efeito': tamanho_efeito
  })

df_resultados_d_cohen = pd.DataFrame(resultados_d_cohen)
print(df_resultados_d_cohen)
# Out:
#                                    Comparação  Cohen's d Tamanho do Efeito
# 0                  tempo-50m-cap_VS_plc_aquec  -0.002925           Pequeno
# 1                tempo-50m-cap_VS_plc_nnaquec   0.039700           Pequeno
# 2          tempo-50m-cap_aquec_VS_cap_nnaquec   0.059862           Pequeno
# 3          tempo-50m-plc_aquec_VS_plc_nnaquec   0.017985           Pequeno
# 4                  tempo-15m-cap_VS_plc_aquec  -0.026400           Pequeno
# 5                tempo-15m-cap_VS_plc_nnaquec  -0.025927           Pequeno
# 6          tempo-15m-cap_aquec_VS_cap_nnaquec  -0.092189           Pequeno
# 7          tempo-15m-plc_aquec_VS_plc_nnaquec  -0.100732           Pequeno
# 8            tempo-35m-cap_aquec_VS_plc_aquec   0.063262           Pequeno
# 9        tempo-35m-cap_nnaquec_VS_plc_nnaquec   0.052688           Pequeno
# 10         tempo-35m-cap_aquec_VS_cap_nnaquec   0.047298           Pequeno
# 11         tempo-35m-plc_aquec_VS_plc_nnaquec   0.052368           Pequeno
# 12               lactato-pre-cap_VS_plc_aquec   0.062144           Pequeno
# 13             lactato-pre-cap_VS_plc_nnaquec  -0.199387           Pequeno
# 14       lactato-pre-cap_aquec_VS_cap_nnaquec  -1.224721            Grande
# 15       lactato-pre-plc_aquec_VS_plc_nnaquec  -1.127440            Grande
# 16          lactato-pos_1min_cap_VS_plc_aquec  -0.277508             Médio
# 17        lactato-pos_1min_cap_VS_plc_nnaquec  -0.366022             Médio
# 18  lactato-pos_1min_cap_aquec_VS_cap_nnaquec  -0.919727            Grande
# 19  lactato-pos_1min_plc_aquec_VS_plc_nnaquec  -0.867161            Grande
# 20          lactato-pos_3min_cap_VS_plc_aquec  -0.278431             Médio
# 21        lactato-pos_3min_cap_VS_plc_nnaquec   0.073741           Pequeno
# 22  lactato-pos_3min_cap_aquec_VS_cap_nnaquec  -0.543583            Grande
# 23  lactato-pos_3min_plc_aquec_VS_plc_nnaquec  -0.774674            Grande
# 24                       scm-cap_VS_plc_aquec  -0.019114           Pequeno
# 25                     scm-cap_VS_plc_nnaquec  -0.294289             Médio
# 26               scm-cap_aquec_VS_cap_nnaquec   0.575209            Grande
# 27               scm-plc_aquec_VS_plc_nnaquec   0.302221             Médio
# 28                       pse-cap_VS_plc_aquec  -0.553519            Grande
# 29                     pse-cap_VS_plc_nnaquec  -0.289346             Médio
# 30               pse-cap_aquec_VS_cap_nnaquec   0.235339             Médio
# 31               pse-plc_aquec_VS_plc_nnaquec   0.000000           Pequeno
# 32                 motivacao-cap_VS_plc_aquec   0.324517             Médio
# 33               motivacao-cap_VS_plc_nnaquec  -0.142983           Pequeno
# 34         motivacao-cap_aquec_VS_cap_nnaquec  -0.201500             Médio
# 35         motivacao-plc_aquec_VS_plc_nnaquec   0.269404             Médio
# 36                preparacao-cap_VS_plc_aquec   0.137963           Pequeno
# 37              preparacao-cap_VS_plc_nnaquec  -0.114848           Pequeno
# 38        preparacao-cap_aquec_VS_cap_nnaquec  -0.161127           Pequeno
# 39        preparacao-plc_aquec_VS_plc_nnaquec   0.092134           Pequeno
# 40              brums_fadiga-cap_VS_plc_aquec  -0.592670            Grande
# 41            brums_fadiga-cap_VS_plc_nnaquec   0.051450           Pequeno
# 42      brums_fadiga-cap_aquec_VS_cap_nnaquec   1.031347            Grande
# 43      brums_fadiga-plc_aquec_VS_plc_nnaquec   0.569210            Grande
# 44               brums-vigor-cap_VS_plc_aquec   0.162079           Pequeno
# 45             brums-vigor-cap_VS_plc_nnaquec  -0.032454           Pequeno
# 46       brums-vigor-cap_aquec_VS_cap_nnaquec  -0.055258           Pequeno
# 47       brums-vigor-plc_aquec_VS_plc_nnaquec   0.164523           Pequeno
